# %% [markdown]
# # Cohen - 2021 - Linear Algebra theory, intuition, code

# %%
# import libraries

# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy as sp
from IPython.display import Image

# %% [markdown]
# ## 5.8 "Shifting" a matrix

# %% [markdown]
# Why would we need to do this?
# * Regularization
#     * solve systems of equations
#     * fit statistical models to low-rank data

# %%
display(Image('data/20072024_073233.png'))

a = np.array(([[0,1,2,0],[3,4,5,1],[6,7,8,2],[9,10,11,3]])) # (4, 4)

scale_lam = 0.1
lam = np.eye(4)

a_tilde = a + np.dot(scale_lam, lam)

display(j)
# Out:
# array([[ 0.1,  1. ,  2. ,  0. ],
#        [ 3. ,  4.1,  5. ,  1. ],
#        [ 6. ,  7. ,  8.1,  2. ],
#        [ 9. , 10. , 11. ,  3.1]])

# %%
display(Image('data/20072024_074156.png'))

a = np.array(([[1,3,0],[1,3,0],[2,2,7]]))

scale_lam = 0.1
lam = np.eye(3) # lambda


# display(a,lam)
# display(a+np.dot(scale_lam,lam))

a + np.dot(scale_lam, lam)
# Out:
# array([[1.1, 3. , 0. ],
#        [1. , 3.1, 0. ],
#        [2. , 2. , 7.1]])
