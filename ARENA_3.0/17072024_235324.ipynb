# %% [markdown]
# # Cohen - 2021 - Linear Algebra theory, intuition, code

# %%
# import libraries

# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy as sp
from IPython.display import Image

# %% [markdown]
# ## 5.9 Diagonal and trace

# %%
display(Image('data/20072024_082306.png'))

# %%
matrix0 = np.array(([[5,3,8],[1,0,4],[8,6,2]]))
np.diag(matrix0) # co-variance of
# Out:
# array([5, 0, 2])

# %%
D = np.array(([[5,30,45],
                [7,35,40],
                [3,25,50],
                [6,32,42]]))

display(np.mean(D, axis=0))
# Out:
# array([ 5.25, 30.5 , 44.25])
